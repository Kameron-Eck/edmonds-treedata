# %%
# !pip install rasterio pyproj tqdm -q
from google.colab import drive; drive.mount('/content/drive')
import os; os.environ["DL_NAMES"] = "edmonds_2017"
# %run /content/drive/MyDrive/treedata/Scripts/unified_downloader.py
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Filtering to groups: {'Edmonds'}
# Filtering to names: {'edmonds_2017'}
# ...
#   UNIFIED AERIAL IMAGERY DOWNLOADER v3 — Edmonds WA
#   Sources: 1  |  Output: /content/drive/MyDrive/treedata/Full_Image
#   Export workers: 4  |  Tile workers: 12
#   Skip threshold: >1 MB  |  Timeout: 60s
# ...
#   Edmonds: 1
#
# [1/1] Edmonds/edmonds_2017  (tiles)
#     Probed: maxPx=8192x4100 pixelType=U8
#     z=21 res=0.0746m  grid=581x828=481,068  output=148736x211968px (94.6 GB)  workers=12
# ...
#     edmonds_2017:  26%|██▌       | 125952/481068 [33:32<1:41:07, 58.53tile/s]
# ...
# ...
#     edmonds_2017: 100%|██████████| 481068/481068 [2:32:44<00:00, 52.49tile/s]
#     472,353/481,068 tiles with data
#     Saved: edmonds_2017_image.tif (48377.4 MB, 3b, EPSG:3857)
#
# ...
#   DONE: 1 downloaded, 0 skipped, 0 failed
#   Total: 1/1
# ...
